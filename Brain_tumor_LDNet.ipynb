# %% [markdown]
# <a href="https://colab.research.google.com/github/heidarimohsen92/LDNet/blob/main/Brain_tumor_LDNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import sys
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf  
import tensorflow.keras.backend as K
from skimage.transform import resize
from skimage.io import imread, imshow, imread_collection, concatenate_images
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv2D, Concatenate, Activation, MaxPool2D, UpSampling2D, Input, Dropout
from tensorflow.keras.layers import Activation, BatchNormalization, Lambda, Add, Multiply, add

# %% [markdown]
# ### Download and Load the [`brain-tumor-segmentation`](https://www.kaggle.com/datasets/tinashri/brain-tumor-segmentation-datasets) dataset from kaggle

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d tinashri/brain-tumor-segmentation-datasets
# !unzip /content/brain-tumor-segmentation-datasets.zip

# !rm -rf brain-tumor-segmentation-datasets.zip

# %% [markdown]
# # Dataset Preprocessing

# %%
# Create Lists of images and masks in Augmented paths
def label_data(fn): 
    return str(fn).replace("images", "masks")

data_dir = '/content/data/images'
img_path = sorted( [os.path.join(data_dir , i) for i in os.listdir(data_dir)] )
mask_path = [label_data(i) for i in img_path]

print("number of images is : {}".format(len(img_path)))
print("number of mask is : {} \n".format(len(mask_path)))
for input_path, target_path in zip(img_path[:10], mask_path[:10]):
    print(input_path, "|", target_path)
# Out:
# number of images is : 3064
# number of mask is : 3064
#
# /content/data/images/1.png | /content/data/masks/1.png
# /content/data/images/10.png | /content/data/masks/10.png
# /content/data/images/100.png | /content/data/masks/100.png
# /content/data/images/1000.png | /content/data/masks/1000.png
# /content/data/images/1001.png | /content/data/masks/1001.png
# /content/data/images/1002.png | /content/data/masks/1002.png
# /content/data/images/1003.png | /content/data/masks/1003.png
# /content/data/images/1004.png | /content/data/masks/1004.png
# /content/data/images/1005.png | /content/data/masks/1005.png
# /content/data/images/1006.png | /content/data/masks/1006.png

# %% [markdown]
# **Creating our image masks of dimension 256 x 256 (black images)**

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3

X_data = np.zeros((len(img_path), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_data = np.zeros((len(mask_path), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool_)
# Re-sizing our training images to 256 x 256
# Note sys.stdout prints info that can be cleared unlike print.
# Using TQDM allows us to create progress bars
sys.stdout.flush()

print('Getting and resizing training images ... ')
for n, img_dir in tqdm(enumerate(img_path), total=len(img_path)):
    img = imread(img_dir)
    img = np.expand_dims(resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                  preserve_range=True), axis=-1)
    X_data[n] = img

# data mask
print('\nGetting and resizing test mask ... ')
for n, mask_dir in tqdm(enumerate(mask_path), total=len(mask_path)):
    mask = imread(mask_dir)
    mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                  preserve_range=True), axis=-1)
    Y_data[n] = mask
# Out:
# Getting and resizing training images ...
# 100%|██████████| 3064/3064 [01:04<00:00, 47.44it/s]
# Getting and resizing test mask ...
# 100%|██████████| 3064/3064 [00:35<00:00, 85.11it/s]

# %% [markdown]
# ## Split Data

# %%
# Splitting the data into train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size = 0.05, random_state=42)
print("train images shape:{}".format(X_train.shape), "|" , "train mask shape:{} \n".format(Y_train.shape))
print("test images shape:{}".format(X_test.shape), "|" , "test mask shape:{} \n".format(Y_test.shape))
# Out:
# train images shape:(2910, 256, 256, 3) | train mask shape:(2910, 256, 256, 1)
#
# test images shape:(154, 256, 256, 3) | test mask shape:(154, 256, 256, 1)

# %% [markdown]
# ### **DropBlock2D LDNet**

# %%
# DropBlock: A regularization method for convolutional networks
# arXiv. https://arxiv.org/abs/1810.12890

def _bernoulli(shape, mean):
    return tf.nn.relu(tf.sign(mean - tf.random.uniform(shape, minval=0, maxval=1, dtype=tf.float32)))


class DropBlock2D(tf.keras.layers.Layer):
    def __init__(self, keep_prob, block_size, scale=True,name=None, **kwargs):
        super(DropBlock2D, self).__init__(name="DropBlock2D")
        self.keep_prob = float(keep_prob) if isinstance(keep_prob, int) else keep_prob
        self.block_size = int(block_size)
        self.names = name
        self.scale = tf.constant(scale, dtype=tf.bool) if isinstance(scale, bool) else scale
        super(DropBlock2D, self).__init__(**kwargs)
        
    def get_config(self):
        config = super().get_config().copy()
        config.update( {"block_size": self.block_size,"keep_prob": self.keep_prob,"name": self.names })
        return config

    def compute_output_shape(self, input_shape):
        return input_shape

    def build(self, input_shape):
        assert len(input_shape) == 4
        _, self.h, self.w, self.channel = input_shape.as_list()
        # pad the mask
        p1 = (self.block_size - 1) // 2
        p0 = (self.block_size - 1) - p1
        self.padding = [[0, 0], [p0, p1], [p0, p1], [0, 0]]
        self.set_keep_prob()
        super(DropBlock2D, self).build(input_shape)

    def call(self, inputs, training=None, **kwargs):
        def drop():
            mask = self._create_mask(tf.shape(inputs))
            output = inputs * mask
            output = tf.cond(self.scale,
                             true_fn=lambda: output *tf.cast(tf.size(mask), dtype=tf.float32)  / tf.reduce_sum(mask),
                             false_fn=lambda: output)
            return output

        if training is None:
            training = K.learning_phase()
        output = tf.cond(tf.logical_or(tf.logical_not(training), tf.equal(self.keep_prob, 1.0)),
                         true_fn=lambda: inputs,
                         false_fn=drop)
        return output

    def set_keep_prob(self, keep_prob=None):
        """This method only supports Eager Execution"""
        if keep_prob is not None:
            self.keep_prob = keep_prob
        w, h = tf.cast(self.w, dtype=tf.float32), tf.cast(self.h, dtype=tf.float32)
        
        self.gamma = (1. - self.keep_prob) * (w * h) / (self.block_size ** 2) / \
                     ((w - self.block_size + 1) * (h - self.block_size + 1))

    def _create_mask(self, input_shape):
        sampling_mask_shape = tf.stack([input_shape[0],
                                       self.h - self.block_size + 1,
                                       self.w - self.block_size + 1,
                                       self.channel])
        mask = _bernoulli(sampling_mask_shape, self.gamma)
        mask = tf.pad(mask, self.padding)
        mask = tf.nn.max_pool(mask, [1, self.block_size, self.block_size, 1], [1, 1, 1, 1], 'SAME')
        mask = 1 - mask
        return mask

# %% [markdown]
# ### **Attention_Block LDNet**

# %%
def Attention_Block(x, g, inter_shape, name="Attention_Block"):
    #Gated attention block used in skip connections in the U-Net
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(g)

    # Getting the gating signal to the same number of filters as the inter_shape
    phi_g = Conv2D(filters=inter_shape,
                   kernel_size=1,
                   strides=1,
                   padding='same')(g)

    # Getting the x signal to the same shape as the gating signal
    theta_x = Conv2D(filters=inter_shape,
                     kernel_size=3,
                     strides=(shape_x[1] // shape_g[1],
                              shape_x[2] // shape_g[2]),
                     padding='same')(x)

    # Element-wise addition of the gating and x signals
    add_xg = Add()([phi_g, theta_x])
    add_xg = Activation('relu')(add_xg)

    # 1x1x1 convolution
    psi = Conv2D(filters=1, kernel_size=1, padding='same')(add_xg)
    psi = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(psi)

    # Upsampling psi back to the original dimensions of x signal
    upsample_sigmoid_xg = UpSampling2D(size=(shape_x[1] // shape_sigmoid[1],
                                             shape_x[2] //
                                             shape_sigmoid[2]))(psi)


    # Element-wise multiplication of attention coefficients back onto original x signal
    attn_coefficients = Multiply()([upsample_sigmoid_xg, x])

    # Final 1x1x1 convolution to consolidate attention signal to original x dimensions
    output = Conv2D(filters=inter_shape,
                    kernel_size=1,
                    strides=1,
                    padding='same')(attn_coefficients)
    output = BatchNormalization(name=name)(output)
    return output

# %% [markdown]
# ### **Up_Block LDNet**

# %%
# Up_Block
def Up_Block(input_layer, filters=128, kernel_size=3, name="Up_Block"):
    x = UpSampling2D((2,2))(input_layer) 
    x = Conv2D(filters, kernel_size=kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    output = Activation("relu", name=name)(x)
    return output

# %% [markdown]
# # Building our LDNet Model

# %%
n_label = 1

inputs = Input(shape=(256,256,3), name = "Main_Input")
# norm = Lambda(lambda x: x / 255) (inputs)

''' ENCODER ''' 
# Conv-1 block
down_conv_1 = Conv2D(32, kernel_size=(3,3), padding="same")(inputs)
down_conv_1 = BatchNormalization()(down_conv_1)
down_conv_1 = Conv2D(32, kernel_size=(3,3), padding='same')(down_conv_1)
down_conv_1 = BatchNormalization()(down_conv_1)
down_conv_1 = Activation("relu", name="down_conv_1")(down_conv_1)
down_conv_1 = DropBlock2D(keep_prob=0.0, block_size=5)(down_conv_1)
down_conv_1 = MaxPool2D(pool_size=(2,2), strides=(2,2))(down_conv_1)
# Conv-2 block
down_conv_2 = Conv2D(64, kernel_size=(3,3), padding="same")(down_conv_1)
down_conv_2 = BatchNormalization()(down_conv_2)
down_conv_2 = Conv2D(64, kernel_size=(3,3), padding='same')(down_conv_2)
down_conv_2 = BatchNormalization()(down_conv_2)
down_conv_2 = Activation("relu", name="down_conv_2")(down_conv_2)
down_conv_2 = DropBlock2D(keep_prob=0.0, block_size=5)(down_conv_2)
down_conv_2 = MaxPool2D(pool_size=(2,2), strides=(2,2))(down_conv_2)
# Conv-3 block
down_conv_3 = Conv2D(128, kernel_size=(3,3), padding="same")(down_conv_2)
down_conv_3 = BatchNormalization()(down_conv_3)
down_conv_3 = Conv2D(128, kernel_size=(3,3), padding='same')(down_conv_3)
down_conv_3 = BatchNormalization()(down_conv_3)
down_conv_3 = Activation("relu", name="down_conv_3")(down_conv_3)
down_conv_3 = DropBlock2D(keep_prob=0.0, block_size=5)(down_conv_3)
down_conv_3 = MaxPool2D(pool_size=(2,2), strides=(2,2))(down_conv_3)
# Conv-4 block
down_conv_4 = Conv2D(256, kernel_size=(3,3), padding="same")(down_conv_3)
down_conv_4 = BatchNormalization()(down_conv_4)
down_conv_4 = Conv2D(256, kernel_size=(3,3), padding='same')(down_conv_4)
down_conv_4 = BatchNormalization()(down_conv_4)
down_conv_4 = Activation("relu", name="down_conv_4")(down_conv_4)
down_conv_4 = DropBlock2D(keep_prob=0.0, block_size=5)(down_conv_4)

''' Astrous spatial Pooling block '''
box1 = Conv2D(256, kernel_size=(1,1), dilation_rate=1, padding="same", activation='relu')(down_conv_4)
box2 = Conv2D(256, kernel_size=(3,3), dilation_rate=2, padding="same", activation='relu')(down_conv_4)
box3 = Conv2D(256, kernel_size=(3,3), dilation_rate=4, padding="same", activation='relu')(down_conv_4)
box4 = Conv2D(256, kernel_size=(3,3), dilation_rate=8, padding="same", activation='relu')(down_conv_4)
box5 = Conv2D(256, kernel_size=(3,3), dilation_rate=16, padding="same", activation='relu')(down_conv_4)
box6 = Conv2D(256, kernel_size=(3,3), dilation_rate=32, padding="same", activation='relu')(down_conv_4)
concatted = Concatenate()([box1, box2, box3, box4, box5, box6])
ASPP = Conv2D(256, kernel_size=(1,1), padding='same', name="ASPP")(concatted)

''' Decoder '''
# up_block & attention_block
up_block_4 = Up_Block(ASPP, filters=128, kernel_size=3, name="up_block_4")
attention_4 = Attention_Block(up_block_4, down_conv_3, 256, name="attention_4")
# Conv-3 block
up_conv_3 = Conv2D(128, kernel_size=(3,3), padding="same")(attention_4)
up_conv_3 = BatchNormalization()(up_conv_3)
up_conv_3 = Conv2D(128, kernel_size=(3,3), padding='same')(up_conv_3)
up_conv_3 = BatchNormalization()(up_conv_3)
up_conv_3 = Activation("relu", name="up_conv_3")(up_conv_3)
# up_block & attention_block
up_block_3 = Up_Block(up_conv_3, filters=64, kernel_size=3, name="up_block_3")
attention_3 = Attention_Block(up_block_3, down_conv_2, 128, name="attention_3")
# Conv-2 block
up_conv_2 = Conv2D(64, kernel_size=(3,3), padding="same")(attention_3)
up_conv_2 = BatchNormalization()(up_conv_2)
up_conv_2 = Conv2D(64, kernel_size=(3,3), padding='same')(up_conv_2)
up_conv_2 = BatchNormalization()(up_conv_2)
up_conv_2 = Activation("relu", name="up_conv_2")(up_conv_2)
# up_block & attention_block
up_block_2 = Up_Block(up_conv_2, filters=32, kernel_size=3, name="up_block_2")
attention_2 = Attention_Block(up_block_2, down_conv_1, 64, name="attention_2")
# Conv-1 block
up_conv_1 = Conv2D(32, kernel_size=(3,3), padding="same")(attention_2)
up_conv_1 = BatchNormalization()(up_conv_1)
up_conv_1 = Conv2D(32, kernel_size=(3,3), padding='same')(up_conv_1)
up_conv_1 = BatchNormalization()(up_conv_1)
up_conv_1 = Activation("relu", name="up_conv_1")(up_conv_1)
# Output
outputs = Conv2D(n_label, kernel_size=(1,1), activation='sigmoid')(up_conv_1)

tf.keras.backend.clear_session()
model = Model(inputs=inputs, outputs=outputs, name="LDNet")
model.summary()
# Out:
# Model: "LDNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Main_Input (InputLayer)        [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['Main_Input[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  down_conv_1 (Activation)       (None, 256, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  drop_block2d (DropBlock2D)     (None, 256, 256, 32  0           ['down_conv_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['drop_block2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  down_conv_2 (Activation)       (None, 128, 128, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  drop_block2d_1 (DropBlock2D)   (None, 128, 128, 64  0           ['down_conv_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['drop_block2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  down_conv_3 (Activation)       (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  drop_block2d_2 (DropBlock2D)   (None, 64, 64, 128)  0           ['down_conv_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['drop_block2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  down_conv_4 (Activation)       (None, 32, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  drop_block2d_3 (DropBlock2D)   (None, 32, 32, 256)  0           ['down_conv_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 256)  65792       ['drop_block2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 256)  590080      ['drop_block2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  590080      ['drop_block2d_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['drop_block2d_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  590080      ['drop_block2d_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  590080      ['drop_block2d_3[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 1536  0           ['conv2d_8[0][0]',
#                                 )                                 'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  ASPP (Conv2D)                  (None, 32, 32, 256)  393472      ['concatenate[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['ASPP[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  295040      ['up_sampling2d[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_14[0][0]']
#  rmalization)
#
#  up_block_4 (Activation)        (None, 64, 64, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 256)  33024       ['max_pooling2d_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 256)  295168      ['up_block_4[0][0]']
#
#  add (Add)                      (None, 32, 32, 256)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  activation (Activation)        (None, 32, 32, 256)  0           ['add[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 1)    257         ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 1)    0           ['conv2d_17[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_1[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 128)  0           ['up_sampling2d_1[0][0]',
#                                                                   'up_block_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 256)  33024       ['multiply[0][0]']
#
#  attention_4 (BatchNormalizatio  (None, 64, 64, 256)  1024       ['conv2d_18[0][0]']
#  n)
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 128)  295040      ['attention_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_19[0][0]']
#  rmalization)
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  up_conv_3 (Activation)         (None, 64, 64, 128)  0           ['batch_normalization_10[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 12  0          ['up_conv_3[0][0]']
#                                 8)
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 64  73792       ['up_sampling2d_2[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 64  256        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  up_block_3 (Activation)        (None, 128, 128, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  73856       ['up_block_3[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 128)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  activation_2 (Activation)      (None, 64, 64, 128)  0           ['add_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 1)    129         ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 64, 64, 1)    0           ['conv2d_24[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 128, 64  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'up_block_3[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 12  8320        ['multiply_1[0][0]']
#                                 8)
#
#  attention_3 (BatchNormalizatio  (None, 128, 128, 12  512        ['conv2d_25[0][0]']
#  n)                             8)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  73792       ['attention_3[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 64  256        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  up_conv_2 (Activation)         (None, 128, 128, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 64  0          ['up_conv_2[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 32  18464       ['up_sampling2d_4[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 32  128        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  up_block_2 (Activation)        (None, 256, 256, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 64  2112        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 64  18496       ['up_block_2[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 64  0           ['conv2d_29[0][0]',
#                                 )                                 'conv2d_30[0][0]']
#
#  activation_4 (Activation)      (None, 128, 128, 64  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 1)  65          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 128, 128, 1)  0           ['conv2d_31[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 256, 256, 32  0           ['up_sampling2d_5[0][0]',
#                                 )                                 'up_block_2[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 64  2112        ['multiply_2[0][0]']
#                                 )
#
#  attention_2 (BatchNormalizatio  (None, 256, 256, 64  256        ['conv2d_32[0][0]']
#  n)                             )
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 32  18464       ['attention_2[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 32  128        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_15[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 32  128        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  up_conv_1 (Activation)         (None, 256, 256, 32  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 1)  33          ['up_conv_1[0][0]']
#
# ==================================================================================================
# Total params: 6,033,508
# Trainable params: 6,029,348
# Non-trainable params: 4,160
# __________________________________________________________________________________________________

# %% [markdown]
# ## Metric

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# ### Compile The Model

# %%
# Compile The Model
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=[dice_coef])

# %% [markdown]
# # **Fit our model**

# %%
# Initialize our callbacks
checkpoint_filepath = "save_model/best-weights"
checkpoint = ModelCheckpoint(checkpoint_filepath,
                             monitor="val_loss",
                             mode="min",
                             verbose=1,
                             save_best_only=True,
                             save_weights_only=True)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 7,
                          verbose = 1,
                          restore_best_weights=True)

# Fit our model 
history = model.fit(X_train, Y_train, validation_split=0.20,
                    batch_size=8, epochs=100, 
                    callbacks=[earlystop, checkpoint])
# Out:
# Epoch 1/100
# 291/291 [==============================] - ETA: 0s - loss: 0.1498 - dice_coef: 0.0372
# Epoch 1: val_loss improved from inf to 0.09899, saving model to save_model/best-weights
# 291/291 [==============================] - 135s 381ms/step - loss: 0.1498 - dice_coef: 0.0372 - val_loss: 0.0990 - val_dice_coef: 0.0261
# Epoch 2/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0748 - dice_coef: 0.0829
# Epoch 2: val_loss improved from 0.09899 to 0.09295, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 367ms/step - loss: 0.0748 - dice_coef: 0.0829 - val_loss: 0.0930 - val_dice_coef: 0.0925
# Epoch 3/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0562 - dice_coef: 0.2209
# Epoch 3: val_loss did not improve from 0.09295
# 291/291 [==============================] - 106s 366ms/step - loss: 0.0562 - dice_coef: 0.2209 - val_loss: 0.1404 - val_dice_coef: 0.1587
# Epoch 4/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0491 - dice_coef: 0.3072
# Epoch 4: val_loss improved from 0.09295 to 0.07911, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 367ms/step - loss: 0.0491 - dice_coef: 0.3072 - val_loss: 0.0791 - val_dice_coef: 0.1289
# Epoch 5/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0451 - dice_coef: 0.3563
# Epoch 5: val_loss improved from 0.07911 to 0.05714, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 367ms/step - loss: 0.0451 - dice_coef: 0.3563 - val_loss: 0.0571 - val_dice_coef: 0.2391
# Epoch 6/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0428 - dice_coef: 0.3842
# Epoch 6: val_loss did not improve from 0.05714
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0428 - dice_coef: 0.3842 - val_loss: 0.0581 - val_dice_coef: 0.2280
# Epoch 7/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0409 - dice_coef: 0.4070
# Epoch 7: val_loss improved from 0.05714 to 0.04880, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 366ms/step - loss: 0.0409 - dice_coef: 0.4070 - val_loss: 0.0488 - val_dice_coef: 0.3059
# Epoch 8/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0396 - dice_coef: 0.4239
# Epoch 8: val_loss improved from 0.04880 to 0.04777, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 367ms/step - loss: 0.0396 - dice_coef: 0.4239 - val_loss: 0.0478 - val_dice_coef: 0.2579
# Epoch 9/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0381 - dice_coef: 0.4453
# Epoch 9: val_loss did not improve from 0.04777
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0381 - dice_coef: 0.4453 - val_loss: 0.0581 - val_dice_coef: 0.3849
# Epoch 10/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0364 - dice_coef: 0.4623
# Epoch 10: val_loss did not improve from 0.04777
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0364 - dice_coef: 0.4623 - val_loss: 0.0495 - val_dice_coef: 0.3199
# Epoch 11/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0348 - dice_coef: 0.4908
# Epoch 11: val_loss improved from 0.04777 to 0.04672, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 366ms/step - loss: 0.0348 - dice_coef: 0.4908 - val_loss: 0.0467 - val_dice_coef: 0.3459
# Epoch 12/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0346 - dice_coef: 0.4880
# Epoch 12: val_loss improved from 0.04672 to 0.04255, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 366ms/step - loss: 0.0346 - dice_coef: 0.4880 - val_loss: 0.0426 - val_dice_coef: 0.3842
# Epoch 13/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0344 - dice_coef: 0.4927
# Epoch 13: val_loss improved from 0.04255 to 0.03746, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 367ms/step - loss: 0.0344 - dice_coef: 0.4927 - val_loss: 0.0375 - val_dice_coef: 0.4769
# Epoch 14/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0341 - dice_coef: 0.4986
# Epoch 14: val_loss improved from 0.03746 to 0.03690, saving model to save_model/best-weights
# 291/291 [==============================] - 107s 367ms/step - loss: 0.0341 - dice_coef: 0.4986 - val_loss: 0.0369 - val_dice_coef: 0.4896
# Epoch 15/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0320 - dice_coef: 0.5233
# Epoch 15: val_loss did not improve from 0.03690
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0320 - dice_coef: 0.5233 - val_loss: 0.0463 - val_dice_coef: 0.3848
# Epoch 16/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0314 - dice_coef: 0.5291
# Epoch 16: val_loss improved from 0.03690 to 0.03438, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0314 - dice_coef: 0.5291 - val_loss: 0.0344 - val_dice_coef: 0.5171
# Epoch 17/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0304 - dice_coef: 0.5442
# Epoch 17: val_loss improved from 0.03438 to 0.03433, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0304 - dice_coef: 0.5442 - val_loss: 0.0343 - val_dice_coef: 0.4479
# Epoch 18/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0302 - dice_coef: 0.5485
# Epoch 18: val_loss did not improve from 0.03433
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0302 - dice_coef: 0.5485 - val_loss: 0.0435 - val_dice_coef: 0.3819
# Epoch 19/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0295 - dice_coef: 0.5606
# Epoch 19: val_loss improved from 0.03433 to 0.03189, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 366ms/step - loss: 0.0295 - dice_coef: 0.5606 - val_loss: 0.0319 - val_dice_coef: 0.5062
# Epoch 20/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0293 - dice_coef: 0.5566
# Epoch 20: val_loss improved from 0.03189 to 0.03157, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0293 - dice_coef: 0.5566 - val_loss: 0.0316 - val_dice_coef: 0.5084
# Epoch 21/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0281 - dice_coef: 0.5788
# Epoch 21: val_loss did not improve from 0.03157
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0281 - dice_coef: 0.5788 - val_loss: 0.0370 - val_dice_coef: 0.4616
# Epoch 22/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0279 - dice_coef: 0.5834
# Epoch 22: val_loss did not improve from 0.03157
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0279 - dice_coef: 0.5834 - val_loss: 0.0345 - val_dice_coef: 0.4567
# Epoch 23/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0275 - dice_coef: 0.5903
# Epoch 23: val_loss improved from 0.03157 to 0.03075, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0275 - dice_coef: 0.5903 - val_loss: 0.0307 - val_dice_coef: 0.5451
# Epoch 24/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0264 - dice_coef: 0.6000
# Epoch 24: val_loss improved from 0.03075 to 0.02893, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0264 - dice_coef: 0.6000 - val_loss: 0.0289 - val_dice_coef: 0.5686
# Epoch 25/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0257 - dice_coef: 0.6122
# Epoch 25: val_loss did not improve from 0.02893
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0257 - dice_coef: 0.6122 - val_loss: 0.0331 - val_dice_coef: 0.4920
# Epoch 26/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0255 - dice_coef: 0.6140
# Epoch 26: val_loss did not improve from 0.02893
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0255 - dice_coef: 0.6140 - val_loss: 0.0364 - val_dice_coef: 0.5245
# Epoch 27/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0251 - dice_coef: 0.6243
# Epoch 27: val_loss improved from 0.02893 to 0.02668, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0251 - dice_coef: 0.6243 - val_loss: 0.0267 - val_dice_coef: 0.5801
# Epoch 28/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0246 - dice_coef: 0.6256
# Epoch 28: val_loss did not improve from 0.02668
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0246 - dice_coef: 0.6256 - val_loss: 0.0273 - val_dice_coef: 0.5695
# Epoch 29/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0234 - dice_coef: 0.6437
# Epoch 29: val_loss did not improve from 0.02668
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0234 - dice_coef: 0.6437 - val_loss: 0.0269 - val_dice_coef: 0.5766
# Epoch 30/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0231 - dice_coef: 0.6508
# Epoch 30: val_loss did not improve from 0.02668
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0231 - dice_coef: 0.6508 - val_loss: 0.0281 - val_dice_coef: 0.6067
# Epoch 31/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0231 - dice_coef: 0.6453
# Epoch 31: val_loss did not improve from 0.02668
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0231 - dice_coef: 0.6453 - val_loss: 0.0294 - val_dice_coef: 0.5717
# Epoch 32/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0226 - dice_coef: 0.6516
# Epoch 32: val_loss did not improve from 0.02668
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0226 - dice_coef: 0.6516 - val_loss: 0.0284 - val_dice_coef: 0.6277
# Epoch 33/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0220 - dice_coef: 0.6600
# Epoch 33: val_loss did not improve from 0.02668
# 291/291 [==============================] - 105s 363ms/step - loss: 0.0220 - dice_coef: 0.6600 - val_loss: 0.0268 - val_dice_coef: 0.6096
# Epoch 34/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0218 - dice_coef: 0.6653
# Epoch 34: val_loss improved from 0.02668 to 0.02637, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0218 - dice_coef: 0.6653 - val_loss: 0.0264 - val_dice_coef: 0.5868
# Epoch 35/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0216 - dice_coef: 0.6674
# Epoch 35: val_loss did not improve from 0.02637
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0216 - dice_coef: 0.6674 - val_loss: 0.0266 - val_dice_coef: 0.6150
# Epoch 36/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0214 - dice_coef: 0.6717
# Epoch 36: val_loss improved from 0.02637 to 0.02590, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0214 - dice_coef: 0.6717 - val_loss: 0.0259 - val_dice_coef: 0.6619
# Epoch 37/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0205 - dice_coef: 0.6826
# Epoch 37: val_loss did not improve from 0.02590
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0205 - dice_coef: 0.6826 - val_loss: 0.0271 - val_dice_coef: 0.5945
# Epoch 38/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0207 - dice_coef: 0.6815
# Epoch 38: val_loss did not improve from 0.02590
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0207 - dice_coef: 0.6815 - val_loss: 0.0277 - val_dice_coef: 0.6463
# Epoch 39/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0199 - dice_coef: 0.6930
# Epoch 39: val_loss improved from 0.02590 to 0.02358, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0199 - dice_coef: 0.6930 - val_loss: 0.0236 - val_dice_coef: 0.6444
# Epoch 40/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0196 - dice_coef: 0.6970
# Epoch 40: val_loss did not improve from 0.02358
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0196 - dice_coef: 0.6970 - val_loss: 0.0269 - val_dice_coef: 0.6334
# Epoch 41/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0193 - dice_coef: 0.7025
# Epoch 41: val_loss improved from 0.02358 to 0.02269, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0193 - dice_coef: 0.7025 - val_loss: 0.0227 - val_dice_coef: 0.6747
# Epoch 42/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0193 - dice_coef: 0.7019
# Epoch 42: val_loss improved from 0.02269 to 0.02231, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0193 - dice_coef: 0.7019 - val_loss: 0.0223 - val_dice_coef: 0.6495
# Epoch 43/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0186 - dice_coef: 0.7104
# Epoch 43: val_loss did not improve from 0.02231
# 291/291 [==============================] - 105s 363ms/step - loss: 0.0186 - dice_coef: 0.7104 - val_loss: 0.0228 - val_dice_coef: 0.6696
# Epoch 44/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0184 - dice_coef: 0.7161
# Epoch 44: val_loss did not improve from 0.02231
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0184 - dice_coef: 0.7161 - val_loss: 0.0229 - val_dice_coef: 0.6469
# Epoch 45/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0184 - dice_coef: 0.7157
# Epoch 45: val_loss did not improve from 0.02231
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0184 - dice_coef: 0.7157 - val_loss: 0.0250 - val_dice_coef: 0.6548
# Epoch 46/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0181 - dice_coef: 0.7171
# Epoch 46: val_loss improved from 0.02231 to 0.02194, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 364ms/step - loss: 0.0181 - dice_coef: 0.7171 - val_loss: 0.0219 - val_dice_coef: 0.6813
# Epoch 47/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0177 - dice_coef: 0.7213
# Epoch 47: val_loss did not improve from 0.02194
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0177 - dice_coef: 0.7213 - val_loss: 0.0241 - val_dice_coef: 0.6672
# Epoch 48/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0179 - dice_coef: 0.7208
# Epoch 48: val_loss improved from 0.02194 to 0.02150, saving model to save_model/best-weights
# 291/291 [==============================] - 106s 365ms/step - loss: 0.0179 - dice_coef: 0.7208 - val_loss: 0.0215 - val_dice_coef: 0.6632
# Epoch 49/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0171 - dice_coef: 0.7306
# Epoch 49: val_loss did not improve from 0.02150
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0171 - dice_coef: 0.7306 - val_loss: 0.0237 - val_dice_coef: 0.6850
# Epoch 50/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0169 - dice_coef: 0.7335
# Epoch 50: val_loss did not improve from 0.02150
# 291/291 [==============================] - 105s 362ms/step - loss: 0.0169 - dice_coef: 0.7335 - val_loss: 0.0229 - val_dice_coef: 0.6597
# Epoch 51/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0162 - dice_coef: 0.7456
# Epoch 51: val_loss did not improve from 0.02150
# 291/291 [==============================] - 105s 362ms/step - loss: 0.0162 - dice_coef: 0.7456 - val_loss: 0.0220 - val_dice_coef: 0.6827
# Epoch 52/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0169 - dice_coef: 0.7350
# Epoch 52: val_loss did not improve from 0.02150
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0169 - dice_coef: 0.7350 - val_loss: 0.0263 - val_dice_coef: 0.6552
# Epoch 53/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0170 - dice_coef: 0.7370
# Epoch 53: val_loss did not improve from 0.02150
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0170 - dice_coef: 0.7370 - val_loss: 0.0237 - val_dice_coef: 0.6548
# Epoch 54/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0162 - dice_coef: 0.7447
# Epoch 54: val_loss did not improve from 0.02150
# 291/291 [==============================] - 105s 362ms/step - loss: 0.0162 - dice_coef: 0.7447 - val_loss: 0.0221 - val_dice_coef: 0.6972
# Epoch 55/100
# 291/291 [==============================] - ETA: 0s - loss: 0.0160 - dice_coef: 0.7510Restoring model weights from the end of the best epoch: 48.
#
# Epoch 55: val_loss did not improve from 0.02150
# 291/291 [==============================] - 106s 363ms/step - loss: 0.0160 - dice_coef: 0.7510 - val_loss: 0.0227 - val_dice_coef: 0.6484
# Epoch 55: early stopping

# %% [markdown]
# ## evaluate model

# %%
checkpoint_filepath = "save_model/best-weights"
model.load_weights(checkpoint_filepath)
model.evaluate(X_test, Y_test, batch_size=16)
# Out:
# 10/10 [==============================] - 8s 486ms/step - loss: 0.0191 - dice_coef: 0.6873
# [0.019059788435697556, 0.6872953176498413]

# %% [markdown]
# ## Visualize the Results

# %%
dice_coef = history.history['dice_coef']
val_dice_coef = history.history['val_dice_coef']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.plot(dice_coef, label='Training dice_coef')
plt.plot(val_dice_coef, label='Validation dice_coef')
plt.legend(loc='lower right')
plt.ylabel('dice_coef')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation dice_coef')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Showing our predicted masks on our test data

# %%
# Ploting our predicted masks
import random

preds_test = model.predict(X_test, verbose=1)
for n in range(20):
    ix = random.randint(0, len(preds_test))
    plt.figure(figsize=(18,18))

    # Our original test image
    plt.subplot(131)
    plt.imshow(X_test[ix])
    plt.axis('off')
    plt.title("Image")

    # Our original mask  
    plt.subplot(132)
    plt.imshow(np.squeeze(Y_test[ix]), cmap="gray")
    plt.axis('off')
    plt.title("Mask")

    # The mask our LDNet model predicts
    plt.subplot(133)
    plt.imshow(np.squeeze(preds_test[ix]), cmap="gray")
    plt.axis('off')
    plt.title("Predictions")
    plt.show()
# Out:
# 5/5 [==============================] - 15s 2s/step
